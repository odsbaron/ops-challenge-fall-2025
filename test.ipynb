# %%
import polars as pl 
import pandas as pd 
df = pd.read_parquet('/Users/ods/Desktop/汇丰生活/社团/AFT/算子比赛/w2/ops-challenge-fall-2025/testcase/data_for_rolling_regbeta.parquet')

# %%
df['symbol'].unique()
# Out:
# array(['000001.SZ', '000002.SZ', '000004.SZ', ..., '603117.SH',
#        '301512.SZ', '688602.SH'], shape=(4830,), dtype=object)
